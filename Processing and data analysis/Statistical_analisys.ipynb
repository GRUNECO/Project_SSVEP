# %% [markdown]
# <a href="https://colab.research.google.com/github/vhenaoi/ProyectoSSVEP/blob/main/Statistical_analisys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
import os
import scipy.io

# %% [markdown]
# ### **Análisis para todos los sujetos**
# ---

# %%
path_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/potencias_sujetos2020.csv'
path_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/potencias_sujetos2019.csv'

# %%
SNR_path_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/SNR_sujetos2020.csv'
SNR_path_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/SNR_sujetos2019.csv'

# %%
subjects_2019 = pd.read_csv(path_2019, index_col = 0)
subjects_2020 = pd.read_csv(path_2020, index_col = 0)
both_years = pd.concat([subjects_2019, subjects_2020])

# %%
s = []
lista=[2,7,8,14,23]

for i in lista: 

  plt.plot(subjects_2019.columns,subjects_2019.values[i,:])

  s.append(i)

  

plt.xticks(np.arange(0,40,4))

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral de potencia para diferentes sujetos')

plt.axvline(8, color='b', linewidth = 1.2,  ls = '--', alpha = 0.7)

plt.axvline(16, color='b', linewidth = 1.2,  ls = '--', alpha = 0.7)

plt.xlim([0,40])

plt.show()
# Out:
# 7

# %%
avg = both_years.mean(axis = 0).values

plt.xlim([0,40])

plt.xticks(np.arange(0,40,4))

plt.axvline(8, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(16, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.plot(both_years.columns, avg, color = 'black')

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio registros')

# %% [markdown]
# ### **Análisis para ambos ojos**
# ---

# %%
pathboth_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/PotenciasBoth_sujetos2020.csv'
pathboth_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/PotenciasBoth_sujetos2019.csv'

# %%
SNRboth_path_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/SNRboth_sujetos2020.csv'
SNRboth_path_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/SNRboth_sujetos2019.csv'

# %%
both_2019 = pd.read_csv(pathboth_2019, index_col = 0)

both_2020 = pd.read_csv(pathboth_2020, index_col = 0)

bothboth_years = pd.concat([both_2019, both_2020])

bothboth_years.shape

bothboth_years.columns

statistic = bothboth_years[['4.0','8.0']].copy()
# Out:
#          4.0        8.0
# 0  25.045322   8.659290
# 1   9.785142   2.873843
# 2  39.924442   9.967453
# 3  14.951025  12.665285
# 4  59.739857  11.163886

# %%
avg = bothboth_years.mean(axis = 0).values

plt.xlim([0,40])

plt.xticks(np.arange(0,40,4))

plt.axvline(8, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(16, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.plot(bothboth_years.columns, avg, color = 'black')

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio registros ambos ojos')

# %%
SNRboth_2019 = genfromtxt(SNRboth_path_2019, delimiter=',')
print('promedio SNR 2019 para ambos ojos : ', SNRboth_2019.mean() , '\n', 'desviación estandár SNR 2019 para ambos ojos : ' , SNRboth_2019.std(), '\n', '--------------------------')
SNRboth_2020 = genfromtxt(SNRboth_path_2020, delimiter=',')
print('promedio SNR 2020 para ambos ojos : ', SNRboth_2020.mean() , '\n', 'desviación estandár SNR 2020 para ambos ojos : ' , SNRboth_2020.std(), '\n', '--------------------------')
SNRboth = np.concatenate((SNRboth_2019, SNRboth_2020))
print('promedio SNR para ambos ojos : ', SNRboth.mean() , '\n', 'desviación estandár SNR 2020 para ambos ojos : ' , SNRboth.std(), '\n', '--------------------------')
# Out:
# promedio SNR 2019 para ambos ojos :  2.087723987086233
#  desviación estandár SNR 2019 para ambos ojos :  0.7135382567997256
#  --------------------------
# promedio SNR 2020 para ambos ojos :  2.1920251641531787
#  desviación estandár SNR 2020 para ambos ojos :  0.6728882209934243
#  --------------------------
# promedio SNR para ambos ojos :  2.113267132490383
#  desviación estandár SNR 2020 para ambos ojos :  0.7052280074949921
#  --------------------------

# %% [markdown]
# ### **Análisis para ojo izquierdo**
# ---

# %%
pathleft_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/PotenciasLeft_sujetos2020.csv'
pathleft_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/PotenciasLeft_sujetos2019.csv'

# %%
SNRleft_path_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/SNRleft_sujetos2020.csv'
SNRleft_path_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/SNRleft_sujetos2019.csv'

# %%
left_2019 = pd.read_csv(pathleft_2019, index_col = 0)

left_2020 = pd.read_csv(pathleft_2020, index_col = 0)

bothleft_years = pd.concat([left_2019, left_2020])

bothleft_years.shape
# Out:
# (49, 251)

# %%
avg = bothleft_years.mean(axis = 0).values

plt.xlim([0,40])

plt.xticks(np.arange(0,40,4))

plt.axvline(8, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(16, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.plot(bothleft_years.columns, avg, color = 'black')

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio registros ojo izquierdo')

# %%
SNRleft_2019 = genfromtxt(SNRleft_path_2019, delimiter=',')
print('promedio SNR 2019 para ambos ojos : ', SNRleft_2019.mean() , '\n', 'desviación estandár SNR 2019 para ambos ojos : ' , SNRleft_2019.std(), '\n', '--------------------------')
SNRleft_2020 = genfromtxt(SNRleft_path_2020, delimiter=',')
print('promedio SNR 2020 para ambos ojos : ', SNRleft_2020.mean() , '\n', 'desviación estandár SNR 2020 para ambos ojos : ' , SNRleft_2020.std(), '\n', '--------------------------')
SNRleft = np.concatenate((SNRleft_2019, SNRleft_2020))
print('promedio SNR para ambos ojos : ', SNRleft.mean() , '\n', 'desviación estandár SNR para ambos ojos : ' , SNRleft.std(), '\n', '--------------------------')
# Out:
# promedio SNR 2019 para ambos ojos :  2.087723987086233
#  desviación estandár SNR 2019 para ambos ojos :  0.7135382567997256
#  --------------------------
# promedio SNR 2020 para ambos ojos :  2.226152130181065
#  desviación estandár SNR 2020 para ambos ojos :  0.7277436520706196
#  --------------------------
# promedio SNR para ambos ojos :  2.121624756823743
#  desviación estandár SNR para ambos ojos :  0.7195098595972843
#  --------------------------

# %% [markdown]
# ### **Análisis para ojo derecho**
# ---

# %%
pathright_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/PotenciasRight_sujetos2020.csv'
pathright_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/PotenciasRight_sujetos2019.csv'

# %%
SNRright_path_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/SNRright_sujetos2020.csv'
SNRright_path_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/SNRright_sujetos2019.csv'

# %%
right_2019 = pd.read_csv(pathright_2019, index_col = 0)

right_2020 = pd.read_csv(pathright_2020, index_col = 0)

bothright_years = pd.concat([right_2019, right_2020])

bothright_years.shape
# Out:
# (49, 251)

# %%
avg = bothright_years.mean(axis = 0).values

plt.xlim([0,40])

plt.xticks(np.arange(0,40,4))

plt.axvline(8, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(16, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.plot(bothright_years.columns, avg, color = 'black')

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio registros ojo derecho')

# %%
SNRright_2019 = genfromtxt(SNRright_path_2019, delimiter=',')
print('promedio SNR 2019 para ambos ojos : ', SNRright_2019.mean() , '\n', 'desviación estandár SNR 2019 para ambos ojos : ' , SNRright_2019.std(), '\n', '--------------------------')
SNRright_2020 = genfromtxt(SNRright_path_2020, delimiter=',')
print('promedio SNR 2020 para ambos ojos : ', SNRright_2020.mean() , '\n', 'desviación estandár SNR 2020 para ambos ojos : ' , SNRright_2020.std(), '\n', '--------------------------')
SNRright = np.concatenate((SNRright_2019, SNRright_2020))
print('promedio SNR para ambos ojos : ', SNRright.mean() , '\n', 'desviación estandár SNR para ambos ojos : ' , SNRright.std(), '\n', '--------------------------')
# Out:
# promedio SNR 2019 para ambos ojos :  1.7821957805061557
#  desviación estandár SNR 2019 para ambos ojos :  0.8059906662493463
#  --------------------------
# promedio SNR 2020 para ambos ojos :  1.0299518888342638
#  desviación estandár SNR 2020 para ambos ojos :  0.6256065521186065
#  --------------------------
# promedio SNR para ambos ojos :  1.5979727866273252
#  desviación estandár SNR para ambos ojos :  0.831277121774829
#  --------------------------

# %% [markdown]
# ### **Análisis para reposo ambos ojos**
# ---

# %%
path_restboth_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/potencias_repososboth2019.csv'
path_restboth_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/potencias_repososboth2020.csv'

# %%
restboth_2019 = pd.read_csv(path_restboth_2019, index_col = 0)

restboth_2020 = pd.read_csv(path_restboth_2020, index_col = 0)

restboth = pd.concat([restboth_2019, restboth_2020])

rest_statistic = restboth[['4.0', '8.0']].copy()
# Out:
# (49, 2)
# (49, 251)

# %%
avg = restboth.mean(axis = 0).values

avg_2 = bothboth_years.mean(axis = 0).values

plt.xlim([0,40])

plt.xticks(np.arange(0,40,4))

plt.plot(restboth.columns, avg, color = 'black', alpha = 0.7 , ls = "-.")

plt.plot(restboth.columns, avg_2, color = 'red')

plt.axvline(8, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(16, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.legend(['reposo ojos abiertos', 'estimulación binocular'])

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio')

plt.savefig('/content/drive/MyDrive/Visión Sábados/Articulo proyecto'  + '/combined.png')

# %% [markdown]
# ### **Análisis para reposo ojo izquierdo**
# ---

# %%
path_restleft_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/potencias_repososleft2019.csv'
path_restleft_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/potencias_repososleft2020.csv'

# %%
restleft_2019 = pd.read_csv(path_restleft_2019, index_col = 0)

restleft_2020 = pd.read_csv(path_restleft_2020, index_col = 0)

restleft = pd.concat([restleft_2019, restleft_2020])
# Out:
# (49, 251)

# %%
avg = restleft.mean(axis = 0).values

plt.xlim([0,40])

plt.xticks(np.arange(0,40,4))

plt.axvline(8, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(16, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.plot(restleft.columns, avg, color = 'black')

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio registros en reposo 2019')

# %% [markdown]
# ### **Análisis para reposo ojo derecho**
# ---

# %%
path_restright_2019 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2019/potencias_repososright2019.csv'
path_restright_2020 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2020/potencias_repososright2020.csv'

# %%
restright_2019 = pd.read_csv(path_restright_2019, index_col = 0)

restright_2020 = pd.read_csv(path_restright_2020, index_col = 0)

restright = pd.concat([restright_2019, restright_2020])
# Out:
# (49, 251)

# %%
avg = restright.mean(axis = 0).values

plt.xlim([0,40])

plt.xticks(np.arange(0,40,4))

plt.axvline(8, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(16, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.plot(restright.columns, avg, color = 'black')

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio registros en reposo 2019')

# %% [markdown]
# ### **Creación de archivos para prueba pareada**
# ---

# %%
import scipy.io
matlab_file = pd.concat([rest_statistic['4.0'], statistic['4.0'], rest_statistic['8.0'], statistic['8.0'] ], axis = 1)
print(matlab_file)
scipy.io.savemat('/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/stats.mat', mdict={'matlab': matlab_file.values})
# Out:
#          4.0        4.0       8.0        8.0
# 0   2.769167  25.045322  3.874750   8.659290
# 1   3.936996   9.785142  1.515267   2.873843
# 2   5.207046  39.924442  2.069202   9.967453
# 3   9.349412  14.951025  1.487508  12.665285
# 4   3.775545  59.739857  2.536457  11.163886
# 5   3.038042   0.000288  2.417264   0.000189
# 6   7.819345   5.653064  2.554961   1.957443
# 7   6.287475  25.257829  2.219012   3.853231
# 8   2.375350  32.207018  1.987238  19.216636
# 9   4.482570  49.319745  1.819589   8.996868
# 10  4.162452  19.015285  2.229506   4.934402
# 11  4.162452  10.433972  2.229506   1.728044
# 12  7.753805  10.747161  1.920920   2.663359
# 13  7.839129  25.928303  2.599744   3.502461
# 14  6.980939  23.654432  6.256695   5.612751
# 15  4.377654  19.871339  2.816706   7.720444
# 16  3.272542  86.143523  0.904531   7.373887
# 17  2.714827  25.882319  1.975961  17.729474
# 18  6.748163  11.554605  1.348671   9.409644
# 19  4.610351   3.384881  2.109972   4.327146
# 20  2.219533   8.554269  1.416765   2.890199
# 21  0.000718   7.531449  0.000475   4.574361
# 22  4.957760   6.303445  2.015967   5.210199
# 23  2.893310   4.234922  1.233698   5.708777
# 24  7.695130   9.774859  2.110515   2.509756
# 25  2.579849   5.111289  1.265127  12.410170
# 26  4.599430  16.471800  2.451581   6.661860
# 27  4.664101  18.428599  3.467676   8.942210
# 28  7.487626   2.991655  3.543476   6.570512
# 29  1.786713  14.322529  2.408007   2.116504
# 30  2.309740  17.712049  1.043363   8.715991
# 31  2.676937   7.145941  2.068247   0.642873
# 32  1.642061   9.477584  0.602976  10.470399
# 33  2.406423  19.194812  2.323589  20.784368
# 34  1.255207  49.501287  0.792985   7.739394
# 35  2.896276  22.188822  3.009650   3.324621
# 36  3.449758   7.580150  0.737395   1.154339
# 0   4.984021  17.429063  3.498043   1.087198
# 1   5.117503   5.717921  6.972988   4.215892
# 2   3.083504   6.010011  1.967016   9.580835
# 3   3.603076  22.362463  2.024674  10.591914
# 4   1.802822   3.590378  1.329778   4.329715
# 5   2.285826  16.408570  1.711447   8.057287
# 6   3.742515  11.912212  6.576020  13.668933
# 7   1.706846  16.721543  1.366387   2.087123
# 8   7.867800  18.344099  1.757029   5.702029
# 9   7.867800  18.344099  1.757029   5.702029
# 10  7.198429  10.922283  2.001024   5.938822
# 11  2.688575   5.430942  2.256565   3.754943

# %% [markdown]
# ### **Análisis para potencia del 2021**
# ---

# %%
path_2021_sanos = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_sanos/vernier_5hz_logmar_1.csv'
path_2021_CG = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_sujetos_con_gafas/potencias_gafas_vernier_5hz_logmar_1.csv'
path_2021_SG = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_sujetos_con_gafas/potencias_sin_gafas_vernier_5hz_logmar_1.csv'

# %%
for pf in os.listdir(path_2021):

  potency_file_sanos = os.path.join(path_2021, pf)

  name = pf[0:len(pf)-4]

  name = name.replace('_', ' ')

  potency_df = pd.read_csv(potency_file, index_col = False)

  potency_df = potency_df.apply(lambda x: x/x.max(), axis=1)

  avg = potency_df.mean(axis = 0).values

  plt.xlim([0,40])

  plt.xticks(np.arange(0,40,4))

  if '5hz' in pf:

    plt.axvline(10, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)
    plt.axvline(20, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

  if '6hz' in pf:

    plt.axvline(12, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)
    plt.axvline(24, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

  plt.plot(potency_df.columns, avg, color = 'black')

  plt.grid()

  plt.xlabel('frequencia [Hz]')

  plt.ylabel('PSD')

  plt.title('Densidad espectral promedio registros ' + name)

  plt.show()

# %% [markdown]
# ### **Espectro de potencia controles 2021**
# ---

# %%
potency_df_sanos = pd.read_csv(path_2021_sanos, index_col = False)

potency_df_CG = pd.read_csv(path_2021_CG, index_col = False)

potency_df_SG = pd.read_csv(path_2021_SG, index_col = False)

avg_sanos = potency_df_sanos.mean(axis = 0).values

avg_CG = potency_df_CG.mean(axis = 0).values

avg_SG = potency_df_SG.mean(axis = 0).values

plt.figure(figsize = (12,8))

plt.xlim([0,40])

plt.xticks(np.arange(0,40,5))

plt.plot(potency_df_sanos.columns, avg_sanos, color = 'black' )

plt.plot(potency_df_sanos.columns, avg_CG,  color = 'red')

plt.plot(potency_df_sanos.columns, avg_SG,  color = 'green')

plt.axvline(10, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(20, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio estimulación Vernier  5 hz')

plt.legend(['Controles sin alteración visual','Controles con alteración visual corregida','Controles con alteración visual no corregida'])

plt.show()

# %% [markdown]
# ### **Espectro de potencia pacientes 2021**
# ---

# %%
path_2021_pacientes = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_pacientes/gafas_vernier_5hz_logmar_1.csv'
path_2021_pacientes_CG = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_pacientes/vernier_5hz_logmar_1.csv'
path_2021_pacientes_SG = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_pacientes/sin_gafas_vernier_5hz_logmar_1.csv'

# %%
potency_df_pacientes = pd.read_csv(path_2021_pacientes, index_col = False)

potency_df_pacientes_CG = pd.read_csv(path_2021_pacientes_CG, index_col = False)

potency_df_pacientes_SG = pd.read_csv(path_2021_pacientes_SG, index_col = False)

avg_pacientes = potency_df_pacientes.mean(axis = 0).values

avg_pacientes_CG = potency_df_pacientes_CG.mean(axis = 0).values

avg_pacientes_SG = potency_df_pacientes_SG.mean(axis = 0).values

plt.figure(figsize = (12,8))

plt.xlim([0,40])

plt.xticks(np.arange(0,40,5))

plt.plot(potency_df_pacientes.columns, avg_pacientes,  color = 'black')

plt.plot(potency_df_pacientes.columns, avg_pacientes_CG,  color = 'red')

plt.plot(potency_df_pacientes.columns, avg_pacientes_SG,  color = 'green')

plt.axvline(10, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(20, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.legend(['Pacientes sin necesidad de gafas','Pacientes con gafas','Pacientes sin gafas'])

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio estimulación Vernier  5 hz')

plt.show()

# %% [markdown]
# ### **Espectro de potencia controles sanos vs. pacientes sin diagnostico de gafas 2021**
# ---

# %%
plt.figure(figsize = (12,8))

plt.xlim([0,40])

plt.xticks(np.arange(0,40,5))

plt.plot(potency_df_pacientes.columns, avg_sanos,  color = 'black')

plt.plot(potency_df_pacientes.columns, avg_pacientes,  color = 'red')

plt.axvline(10, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(20, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.legend(['Controles sin alteración visual','Pacientes sin necesidad de gafas'])

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio estimulación Vernier  5 hz')

plt.show()

# %% [markdown]
# ### **Espectro de potencia controles con gafas vs. pacientes con gafas 2021**
# ---

# %%
plt.figure(figsize = (12,8))

plt.xlim([0,40])

plt.xticks(np.arange(0,40,5))

plt.plot(potency_df_pacientes.columns, avg_CG,  color = 'black')

plt.plot(potency_df_pacientes.columns, avg_pacientes_CG,  color = 'red')

plt.axvline(10, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(20, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.legend(['Controles con alteración visual corregida','Pacientes con gafas'])

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio estimulación Vernier  5 hz')

plt.show()

# %% [markdown]
# ### **Espectro de potencia controles sin gafas vs. pacientes sin gafas 2021**
# ---

# %%
plt.figure(figsize = (12,8))
plt.xlim([0,40])

plt.xticks(np.arange(0,40,5))

plt.plot(potency_df_pacientes.columns, avg_SG,  color = 'black')

plt.plot(potency_df_pacientes.columns, avg_pacientes_SG,  color = 'red')

plt.axvline(10, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.axvline(20, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

plt.legend(['Controles con alteración visual no corregida','Pacientes sin gafas'])

plt.grid()

plt.xlabel('frequencia [Hz]')

plt.ylabel('PSD')

plt.title('Densidad espectral promedio estimulación Vernier  5 hz')

plt.show()

# %% [markdown]
# ### **Análisis para potencia de pacientes del 2021**
# ---

# %%
path_pacientes = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_pacientes'

# %%
for pf in os.listdir(path_pacientes):

  potency_file = os.path.join(path_pacientes, pf)

  name = pf[0:len(pf)-4]

  name = name.replace('_', ' ')

  potency_df = pd.read_csv(potency_file, index_col = False)

  avg = potency_df.mean(axis = 0).values

  plt.xlim([0,40])

  plt.xticks(np.arange(0,40,4))

  if '5hz' in pf:

    plt.axvline(10, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)
    plt.axvline(20, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

  if '6hz' in pf:

    plt.axvline(12, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)
    plt.axvline(24, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

  plt.plot(potency_df.columns, avg, color = 'black')

  plt.grid()

  plt.xlabel('frequencia [Hz]')

  plt.ylabel('PSD')

  plt.title('Densidad espectral promedio registros ' + name)
  
  plt.show()
# Out:
# /content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_pacientes/vernier_6hz_logmar_1.csv
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.051871  0.021898  0.001982  ...  5.051810e-15  4.594015e-15  2.652475e-15
# 1  0.062415  0.027269  0.004143  ...  1.881212e-14  1.942867e-14  9.888268e-15
# 2  0.014880  0.006817  0.000762  ...  1.561019e-14  1.604259e-14  7.731306e-15
# 3  0.020967  0.009082  0.000728  ...  7.760316e-15  7.795351e-15  3.623355e-15
#
# [4 rows x 251 columns]
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.004631  0.001955  0.000177  ...  4.510151e-16  4.101440e-16  2.368074e-16
# 1  0.002860  0.001250  0.000190  ...  8.620046e-16  8.902560e-16  4.530980e-16
# 2  0.003524  0.001614  0.000180  ...  3.697040e-15  3.799447e-15  1.831045e-15
# 3  0.004259  0.001845  0.000148  ...  1.576405e-15  1.583522e-15  7.360365e-16
#
# [4 rows x 251 columns]
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.004631  0.001955  0.000177  ...  4.510151e-16  4.101440e-16  2.368074e-16
# 1  0.002860  0.001250  0.000190  ...  8.620046e-16  8.902560e-16  4.530980e-16
# 2  0.003524  0.001614  0.000180  ...  3.697040e-15  3.799447e-15  1.831045e-15
# 3  0.004259  0.001845  0.000148  ...  1.576405e-15  1.583522e-15  7.360365e-16
#
# [4 rows x 251 columns]
# /content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_pacientes/vernier_6hz_logmar_2.csv
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.036860  0.015412  0.001705  ...  1.454025e-14  1.441907e-14  7.612596e-15
# 1  0.065643  0.028842  0.005576  ...  3.864440e-14  3.718309e-14  2.032309e-14
# 2  0.022657  0.009444  0.001099  ...  1.018463e-14  9.782905e-15  5.216975e-15
# 3  0.023008  0.009874  0.000831  ...  1.785786e-14  1.795084e-14  8.841330e-15
#
# [4 rows x 251 columns]
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.003666  0.001533  0.000170  ...  1.446229e-15  1.434176e-15  7.571779e-16
# 1  0.004590  0.002017  0.000390  ...  2.702401e-15  2.600211e-15  1.421192e-15
# 2  0.003806  0.001587  0.000185  ...  1.711042e-15  1.643551e-15  8.764638e-16
# 3  0.006273  0.002692  0.000227  ...  4.868908e-15  4.894261e-15  2.410571e-15
#
# [4 rows x 251 columns]
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.003666  0.001533  0.000170  ...  1.446229e-15  1.434176e-15  7.571779e-16
# 1  0.004590  0.002017  0.000390  ...  2.702401e-15  2.600211e-15  1.421192e-15
# 2  0.003806  0.001587  0.000185  ...  1.711042e-15  1.643551e-15  8.764638e-16
# 3  0.006273  0.002692  0.000227  ...  4.868908e-15  4.894261e-15  2.410571e-15
#
# [4 rows x 251 columns]
# /content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_pacientes/vernier_6hz_logmar_3.csv
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.025347  0.010668  0.001689  ...  1.472759e-14  1.487954e-14  7.123997e-15
# 1  0.076541  0.034187  0.003004  ...  5.234560e-14  5.023205e-14  2.705953e-14
# 2  0.034335  0.014691  0.001106  ...  1.098949e-14  1.073182e-14  5.513297e-15
# 3  0.015508  0.007022  0.001312  ...  1.212237e-14  1.223707e-14  5.986397e-15
#
# [4 rows x 251 columns]
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.001802  0.000758  0.000120  ...  1.046827e-15  1.057627e-15  5.063689e-16
# 1  0.005036  0.002249  0.000198  ...  3.443834e-15  3.304783e-15  1.780255e-15
# 2  0.004978  0.002130  0.000160  ...  1.593155e-15  1.555800e-15  7.992673e-16
# 3  0.003476  0.001574  0.000294  ...  2.717059e-15  2.742767e-15  1.341767e-15
#
# [4 rows x 251 columns]
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.001802  0.000758  0.000120  ...  1.046827e-15  1.057627e-15  5.063689e-16
# 1  0.005036  0.002249  0.000198  ...  3.443834e-15  3.304783e-15  1.780255e-15
# 2  0.004978  0.002130  0.000160  ...  1.593155e-15  1.555800e-15  7.992673e-16
# 3  0.003476  0.001574  0.000294  ...  2.717059e-15  2.742767e-15  1.341767e-15
#
# [4 rows x 251 columns]
# /content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_pacientes/vernier_6hz_logmar_4.csv
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.021736  0.008925  0.001320  ...  1.239831e-14  1.183549e-14  6.063282e-15
# 1  0.033144  0.013728  0.003575  ...  5.605810e-14  5.587995e-14  2.987332e-14
# 2  0.015562  0.006833  0.001872  ...  8.906471e-15  8.535580e-15  4.433549e-15
# 3  0.013599  0.005370  0.001375  ...  4.986276e-15  4.641470e-15  2.542497e-15
#
# [4 rows x 251 columns]
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.002821  0.001158  0.000171  ...  1.608876e-15  1.535841e-15  7.868064e-16
# 1  0.002170  0.000899  0.000234  ...  3.670985e-15  3.659320e-15  1.956265e-15
# 2  0.002569  0.001128  0.000309  ...  1.470127e-15  1.408907e-15  7.318142e-16
# 3  0.002885  0.001139  0.000292  ...  1.057940e-15  9.847822e-16  5.394425e-16
#
# [4 rows x 251 columns]
#         0.0       0.5       1.0  ...         124.0         124.5         125.0
# 0  0.002821  0.001158  0.000171  ...  1.608876e-15  1.535841e-15  7.868064e-16
# 1  0.002170  0.000899  0.000234  ...  3.670985e-15  3.659320e-15  1.956265e-15
# 2  0.002569  0.001128  0.000309  ...  1.470127e-15  1.408907e-15  7.318142e-16
# 3  0.002885  0.001139  0.000292  ...  1.057940e-15  9.847822e-16  5.394425e-16
#
# [4 rows x 251 columns]
# /content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_pacientes/vernier_6hz_logmar_5.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-16a6265d1db7> in <module>()
#       5   potency_df = pd.read_csv(potency_file, index_col = False)
#       6   print(potency_file)
# ----> 7   print(potency_df)
#       8   potency_df = potency_df.apply(lambda x: x/x.max(), axis=1)
#       9   print(potency_df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __repr__(self)
#     749             line_width=width,
#     750             max_colwidth=max_colwidth,
# --> 751             show_dimensions=show_dimensions,
#     752         )
#     753
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     881                 line_width=line_width,
#     882             )
# --> 883             return formatter.to_string(buf=buf, encoding=encoding)
#     884
#     885     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/format.py in to_string(self, buf, encoding)
#     919         encoding: Optional[str] = None,
#     920     ) -> Optional[str]:
# --> 921         return self.get_result(buf=buf, encoding=encoding)
#     922
#     923     def to_latex(
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     518         """
#     519         with self.get_buffer(buf, encoding=encoding) as f:
# --> 520             self.write_result(buf=f)
#     521             if buf is None:
#     522                 return f.getvalue()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/format.py in write_result(self, buf)
#     857                     # adjoin adds one
#     858                     adj_dif -= col_len + 1
# --> 859                     col_lens = col_lens.drop(mid_ix)
#     860                     n_cols = len(col_lens)
#     861                 # subtract index column
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4515             level=level,
#    4516             inplace=inplace,
# -> 4517             errors=errors,
#    4518         )
#    4519
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3922             else:
#    3923                 new_axis = axis.drop(labels, errors=errors)
# -> 3924             result = self.reindex(**{axis_name: new_axis})
#    3925
#    3926         # Case for non-unique axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4410     )
#    4411     def reindex(self, index=None, **kwargs):
# -> 4412         return super().reindex(index=index, **kwargs)
#    4413
#    4414     def drop(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4462         # perform the reindex on the axes
#    4463         return self._reindex_axes(
# -> 4464             axes, level, limit, tolerance, method, fill_value, copy
#    4465         ).__finalize__(self, method="reindex")
#    4466
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4485                 fill_value=fill_value,
#    4486                 copy=copy,
# -> 4487                 allow_dups=False,
#    4488             )
#    4489
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4530                 fill_value=fill_value,
#    4531                 allow_dups=allow_dups,
# -> 4532                 copy=copy,
#    4533             )
#    4534             # If we've made a copy once, no need to make another one
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1289
#    1290         if axis == 0:
# -> 1291             new_blocks = self._slice_take_blocks_ax0(indexer, fill_value=fill_value)
#    1292         else:
#    1293             new_blocks = [
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice)
#    1360                             axis=0,
#    1361                             new_mgr_locs=slice(0, sllen),
# -> 1362                             fill_value=fill_value,
#    1363                         )
#    1364                     ]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1254
#    1255         new_values = algos.take_nd(
# -> 1256             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1257         )
#    1258
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1735         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1736     )
# -> 1737     func(arr, indexer, out, fill_value)
#    1738
#    1739     if flip_order:
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Análisis para SNR del 2021**
# ---

# %%
SNR_path_2021 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/SNR_sanos'

# %%
for SNRf in os.listdir(SNR_path_2021):

  SNR_file = os.path.join(SNR_path_2021, SNRf)

  SNR_data = genfromtxt(SNR_file, delimiter=',')

  name = SNRf[0:len(SNRf)-4]
  
  name = name.replace('_', ' ')

  print('promedio SNR para ' + name + ' : ' , SNR_data.mean() , '\n', 'STD SNR para ' + name + ' : ' , SNR_data.std(), '\n', '--------------------------')
# Out:
# promedio SNR para SNR sanos ajedrez 5hz logmar 1 :  1.0248535127168212
#  STD SNR para SNR sanos ajedrez 5hz logmar 1 :  0.1648277164683978
#  --------------------------
# promedio SNR para SNR sanos ajedrez 5hz logmar 2 :  1.5184451034115907
#  STD SNR para SNR sanos ajedrez 5hz logmar 2 :  0.3724572727308492
#  --------------------------
# promedio SNR para SNR sanos ajedrez 5hz logmar 3 :  1.3566200367537504
#  STD SNR para SNR sanos ajedrez 5hz logmar 3 :  0.2960922716666714
#  --------------------------
# promedio SNR para SNR sanos ajedrez 5hz logmar 4 :  1.2945549160017789
#  STD SNR para SNR sanos ajedrez 5hz logmar 4 :  0.2563710620785439
#  --------------------------
# promedio SNR para SNR sanos ajedrez 5hz logmar 5 :  1.2437512848087433
#  STD SNR para SNR sanos ajedrez 5hz logmar 5 :  0.2831201262100652
#  --------------------------
# promedio SNR para SNR sanos ajedrez 5hz logmar 6 :  1.340401373553678
#  STD SNR para SNR sanos ajedrez 5hz logmar 6 :  0.33248013167923884
#  --------------------------
# promedio SNR para SNR sanos ajedrez 5hz logmar 7 :  1.3079065446326126
#  STD SNR para SNR sanos ajedrez 5hz logmar 7 :  0.41409324386112034
#  --------------------------
# promedio SNR para SNR sanos ajedrez 6hz logmar 1 :  1.0223610529306026
#  STD SNR para SNR sanos ajedrez 6hz logmar 1 :  0.16740985840424139
#  --------------------------
# promedio SNR para SNR sanos ajedrez 6hz logmar 2 :  1.3956309634552297
#  STD SNR para SNR sanos ajedrez 6hz logmar 2 :  0.3872991780723928
#  --------------------------
# promedio SNR para SNR sanos ajedrez 6hz logmar 3 :  1.3248783072153012
#  STD SNR para SNR sanos ajedrez 6hz logmar 3 :  0.3325095826692683
#  --------------------------
# promedio SNR para SNR sanos ajedrez 6hz logmar 4 :  1.4276469802860763
#  STD SNR para SNR sanos ajedrez 6hz logmar 4 :  0.3346664560673491
#  --------------------------
# promedio SNR para SNR sanos ajedrez 6hz logmar 5 :  1.426291377822777
#  STD SNR para SNR sanos ajedrez 6hz logmar 5 :  0.3498970880977239
#  --------------------------
# promedio SNR para SNR sanos ajedrez 6hz logmar 6 :  1.5131994789677288
#  STD SNR para SNR sanos ajedrez 6hz logmar 6 :  0.4964266186750249
#  --------------------------
# promedio SNR para SNR sanos ajedrez 6hz logmar 7 :  1.3618321550741073
#  STD SNR para SNR sanos ajedrez 6hz logmar 7 :  0.2996452661867492
#  --------------------------
# promedio SNR para SNR sanos vernier 5hz logmar 1 :  2.363730178923236
#  STD SNR para SNR sanos vernier 5hz logmar 1 :  0.6248942029410741
#  --------------------------
# promedio SNR para SNR sanos vernier 5hz logmar 2 :  1.0544305413786017
#  STD SNR para SNR sanos vernier 5hz logmar 2 :  0.16351741016936047
#  --------------------------
# promedio SNR para SNR sanos vernier 5hz logmar 3 :  1.0765524967784357
#  STD SNR para SNR sanos vernier 5hz logmar 3 :  0.1501203164796621
#  --------------------------
# promedio SNR para SNR sanos vernier 5hz logmar 4 :  1.0188251184851282
#  STD SNR para SNR sanos vernier 5hz logmar 4 :  0.13060527065849306
#  --------------------------
# promedio SNR para SNR sanos vernier 5hz logmar 5 :  1.0496142373628636
#  STD SNR para SNR sanos vernier 5hz logmar 5 :  0.2650982293643993
#  --------------------------
# promedio SNR para SNR sanos vernier 5hz logmar 6 :  1.0335348474950978
#  STD SNR para SNR sanos vernier 5hz logmar 6 :  0.15894670354446727
#  --------------------------
# promedio SNR para SNR sanos vernier 5hz logmar 7 :  0.9901364850605262
#  STD SNR para SNR sanos vernier 5hz logmar 7 :  0.17805293493046936
#  --------------------------
# promedio SNR para SNR sanos vernier 6hz logmar 1 :  2.029047943375064
#  STD SNR para SNR sanos vernier 6hz logmar 1 :  0.6045911016584884
#  --------------------------
# promedio SNR para SNR sanos vernier 6hz logmar 2 :  1.0906088625411428
#  STD SNR para SNR sanos vernier 6hz logmar 2 :  0.24856675054091065
#  --------------------------
# promedio SNR para SNR sanos vernier 6hz logmar 3 :  1.0509313778489766
#  STD SNR para SNR sanos vernier 6hz logmar 3 :  0.2531050395314439
#  --------------------------
# promedio SNR para SNR sanos vernier 6hz logmar 4 :  1.131052433187569
#  STD SNR para SNR sanos vernier 6hz logmar 4 :  0.3036604234351971
#  --------------------------
# promedio SNR para SNR sanos vernier 6hz logmar 5 :  1.1243866946102072
#  STD SNR para SNR sanos vernier 6hz logmar 5 :  0.2556876730508542
#  --------------------------
# promedio SNR para SNR sanos vernier 6hz logmar 6 :  1.0637089007757996
#  STD SNR para SNR sanos vernier 6hz logmar 6 :  0.18848303842052436
#  --------------------------
# promedio SNR para SNR sanos vernier 6hz logmar 7 :  1.0480928375898013
#  STD SNR para SNR sanos vernier 6hz logmar 7 :  0.16037983575016276
#  --------------------------

# %% [markdown]
# ### **Análisis para potencia gafas del 2021**
# ---

# %%
path_2021_G = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_sujetos_con_gafas'

# %%
for pfg in os.listdir(path_2021_G):

  potency_file = os.path.join(path_2021_G, pfg)

  name = pfg[0:len(pfg)-4]

  name = name.replace('_', ' ')

  potency_df = pd.read_csv(potency_file, index_col = 0)

  avg = potency_df.mean(axis = 0).values

  plt.xlim([0,40])

  plt.xticks(np.arange(0,40,4))

  if '5hz' in pfg:

    plt.axvline(10, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)
    plt.axvline(20, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

  if '6hz' in pfg:

    plt.axvline(12, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)
    plt.axvline(24, color='b', linewidth = 1.5,  ls = '--', alpha = 0.7)

  plt.plot(potency_df.columns, avg, color = 'black')

  plt.grid()

  plt.xlabel('frequencia [Hz]')

  plt.ylabel('PSD')

  plt.title('Densidad espectral promedio registros ' + name)

  plt.show()

# %% [markdown]
# ### **Análisis para SNR gafas del 2021**
# ---

# %%
SNRg_path_2021 = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/SNR_sujetos_con_gafas'

# %%
for SNRg in os.listdir(SNRg_path_2021):

  SNRg_file = os.path.join(SNRg_path_2021, SNRg)

  SNRg_data = genfromtxt(SNRg_file, delimiter=',')

  name = SNRg[0:len(SNRg)-4]
  
  name = name.replace('_', ' ')

  print('promedio SNR para ' + name + ' : ' , SNRg_data.mean() , '\n', 'STD SNR para ' + name + ' : ' , SNRg_data.std(), '\n', '--------------------------')
# Out:
# promedio SNR para SNR gafas vernier 5hz logmar 1 :  2.4481970632843595
#  STD SNR para SNR gafas vernier 5hz logmar 1 :  0.6610814277730279
#  --------------------------
# promedio SNR para SNR gafas vernier 5hz logmar 2 :  1.1260108011892938
#  STD SNR para SNR gafas vernier 5hz logmar 2 :  0.21842345058192594
#  --------------------------
# promedio SNR para SNR gafas vernier 5hz logmar 3 :  1.1110512984277745
#  STD SNR para SNR gafas vernier 5hz logmar 3 :  0.20631824964556625
#  --------------------------
# promedio SNR para SNR gafas vernier 5hz logmar 4 :  1.0002335823037902
#  STD SNR para SNR gafas vernier 5hz logmar 4 :  0.18247425435092338
#  --------------------------
# promedio SNR para SNR gafas vernier 5hz logmar 5 :  1.046385013667821
#  STD SNR para SNR gafas vernier 5hz logmar 5 :  0.19078018894320875
#  --------------------------
# promedio SNR para SNR gafas vernier 5hz logmar 6 :  1.034679087448918
#  STD SNR para SNR gafas vernier 5hz logmar 6 :  0.2045025144964916
#  --------------------------
# promedio SNR para SNR gafas vernier 5hz logmar 7 :  1.0275377613623748
#  STD SNR para SNR gafas vernier 5hz logmar 7 :  0.12651099153921305
#  --------------------------
# promedio SNR para SNR sin gafas vernier 5hz logmar 1 :  2.195593047195457
#  STD SNR para SNR sin gafas vernier 5hz logmar 1 :  0.7230634862196796
#  --------------------------
# promedio SNR para SNR sin gafas vernier 5hz logmar 2 :  1.116332862376261
#  STD SNR para SNR sin gafas vernier 5hz logmar 2 :  0.22548923299057977
#  --------------------------
# promedio SNR para SNR sin gafas vernier 5hz logmar 3 :  1.178861632412168
#  STD SNR para SNR sin gafas vernier 5hz logmar 3 :  0.2380627458099629
#  --------------------------
# promedio SNR para SNR sin gafas vernier 5hz logmar 4 :  1.0614821813657154
#  STD SNR para SNR sin gafas vernier 5hz logmar 4 :  0.22228060251942627
#  --------------------------
# promedio SNR para SNR sin gafas vernier 5hz logmar 5 :  1.0701594281550937
#  STD SNR para SNR sin gafas vernier 5hz logmar 5 :  0.1775432215918284
#  --------------------------
# promedio SNR para SNR sin gafas vernier 5hz logmar 6 :  1.0507111599892782
#  STD SNR para SNR sin gafas vernier 5hz logmar 6 :  0.15202760246667718
#  --------------------------
# promedio SNR para SNR sin gafas vernier 5hz logmar 7 :  1.02537444802526
#  STD SNR para SNR sin gafas vernier 5hz logmar 7 :  0.1484232885231562
#  --------------------------
# promedio SNR para SNR gafas vernier 6hz logmar 1 :  1.8047686645892838
#  STD SNR para SNR gafas vernier 6hz logmar 1 :  0.5484712273074545
#  --------------------------
# promedio SNR para SNR gafas vernier 6hz logmar 2 :  1.030154488251525
#  STD SNR para SNR gafas vernier 6hz logmar 2 :  0.21559126162146605
#  --------------------------
# promedio SNR para SNR gafas vernier 6hz logmar 3 :  1.0741712414715652
#  STD SNR para SNR gafas vernier 6hz logmar 3 :  0.21130628414223931
#  --------------------------
# promedio SNR para SNR gafas vernier 6hz logmar 4 :  1.0133615129196183
#  STD SNR para SNR gafas vernier 6hz logmar 4 :  0.16759754498891208
#  --------------------------
# promedio SNR para SNR gafas vernier 6hz logmar 6 :  1.016800555622096
#  STD SNR para SNR gafas vernier 6hz logmar 6 :  0.14052523713337772
#  --------------------------
# promedio SNR para SNR gafas vernier 6hz logmar 5 :  1.0333583680985248
#  STD SNR para SNR gafas vernier 6hz logmar 5 :  0.23048491107315264
#  --------------------------
# promedio SNR para SNR gafas vernier 6hz logmar 7 :  0.9944325217450671
#  STD SNR para SNR gafas vernier 6hz logmar 7 :  0.13752481488068233
#  --------------------------
# promedio SNR para SNR sin gafas vernier 6hz logmar 1 :  1.859764196134854
#  STD SNR para SNR sin gafas vernier 6hz logmar 1 :  0.5663564717798972
#  --------------------------
# promedio SNR para SNR sin gafas vernier 6hz logmar 2 :  1.0216209127126414
#  STD SNR para SNR sin gafas vernier 6hz logmar 2 :  0.19919990176048333
#  --------------------------
# promedio SNR para SNR sin gafas vernier 6hz logmar 3 :  1.0395910080799475
#  STD SNR para SNR sin gafas vernier 6hz logmar 3 :  0.16813853841199367
#  --------------------------
# promedio SNR para SNR sin gafas vernier 6hz logmar 4 :  0.9943097873442431
#  STD SNR para SNR sin gafas vernier 6hz logmar 4 :  0.17723666843083652
#  --------------------------
# promedio SNR para SNR sin gafas vernier 6hz logmar 5 :  1.011733049840345
#  STD SNR para SNR sin gafas vernier 6hz logmar 5 :  0.14382543793753302
#  --------------------------
# promedio SNR para SNR sin gafas vernier 6hz logmar 6 :  1.0320602410351098
#  STD SNR para SNR sin gafas vernier 6hz logmar 6 :  0.18794585583917803
#  --------------------------
# promedio SNR para SNR sin gafas vernier 6hz logmar 7 :  1.0138935116355008
#  STD SNR para SNR sin gafas vernier 6hz logmar 7 :  0.1955737313138622
#  --------------------------
# promedio SNR para SNR gafas ajedrez 5hz logmar 1 :  1.004975180097546
#  STD SNR para SNR gafas ajedrez 5hz logmar 1 :  0.1272619746371064
#  --------------------------
# promedio SNR para SNR gafas ajedrez 5hz logmar 2 :  1.3329076977081096
#  STD SNR para SNR gafas ajedrez 5hz logmar 2 :  0.26651181601573537
#  --------------------------
# promedio SNR para SNR gafas ajedrez 5hz logmar 3 :  1.277721623794976
#  STD SNR para SNR gafas ajedrez 5hz logmar 3 :  0.23898542095727024
#  --------------------------
# promedio SNR para SNR gafas ajedrez 5hz logmar 4 :  1.1909185100303734
#  STD SNR para SNR gafas ajedrez 5hz logmar 4 :  0.24699092590024202
#  --------------------------
# promedio SNR para SNR gafas ajedrez 5hz logmar 5 :  1.187865881326169
#  STD SNR para SNR gafas ajedrez 5hz logmar 5 :  0.259315728278902
#  --------------------------
# promedio SNR para SNR gafas ajedrez 5hz logmar 6 :  1.2866872849312376
#  STD SNR para SNR gafas ajedrez 5hz logmar 6 :  0.309114417871158
#  --------------------------
# promedio SNR para SNR gafas ajedrez 5hz logmar 7 :  1.3116672537323981
#  STD SNR para SNR gafas ajedrez 5hz logmar 7 :  0.3621839702837504
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 5hz logmar 1 :  1.0667642487782667
#  STD SNR para SNR sin gafas ajedrez 5hz logmar 1 :  0.18689922908303594
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 5hz logmar 2 :  1.488450324873144
#  STD SNR para SNR sin gafas ajedrez 5hz logmar 2 :  0.31858380979984974
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 5hz logmar 3 :  1.382173350871817
#  STD SNR para SNR sin gafas ajedrez 5hz logmar 3 :  0.27251286715021883
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 5hz logmar 4 :  1.3633582640287034
#  STD SNR para SNR sin gafas ajedrez 5hz logmar 4 :  0.36700604144365395
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 5hz logmar 5 :  1.2694697620585302
#  STD SNR para SNR sin gafas ajedrez 5hz logmar 5 :  0.30980378524416163
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 5hz logmar 6 :  1.3252432393601963
#  STD SNR para SNR sin gafas ajedrez 5hz logmar 6 :  0.31483379769826025
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 5hz logmar 7 :  1.3587447533272916
#  STD SNR para SNR sin gafas ajedrez 5hz logmar 7 :  0.29412563717365264
#  --------------------------
# promedio SNR para SNR gafas ajedrez 6hz logmar 1 :  1.1530107368333213
#  STD SNR para SNR gafas ajedrez 6hz logmar 1 :  0.2322201411516387
#  --------------------------
# promedio SNR para SNR gafas ajedrez 6hz logmar 2 :  1.442178306702465
#  STD SNR para SNR gafas ajedrez 6hz logmar 2 :  0.2639909058858039
#  --------------------------
# promedio SNR para SNR gafas ajedrez 6hz logmar 3 :  1.4009402410899565
#  STD SNR para SNR gafas ajedrez 6hz logmar 3 :  0.2523240579992242
#  --------------------------
# promedio SNR para SNR gafas ajedrez 6hz logmar 4 :  1.3781731104554533
#  STD SNR para SNR gafas ajedrez 6hz logmar 4 :  0.2792193273187187
#  --------------------------
# promedio SNR para SNR gafas ajedrez 6hz logmar 5 :  1.4752876455959114
#  STD SNR para SNR gafas ajedrez 6hz logmar 5 :  0.40520305225743164
#  --------------------------
# promedio SNR para SNR gafas ajedrez 6hz logmar 6 :  1.5222129104141697
#  STD SNR para SNR gafas ajedrez 6hz logmar 6 :  0.452326504569567
#  --------------------------
# promedio SNR para SNR gafas ajedrez 6hz logmar 7 :  1.385645313934823
#  STD SNR para SNR gafas ajedrez 6hz logmar 7 :  0.4416173477508186
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 6hz logmar 1 :  1.0196970582061744
#  STD SNR para SNR sin gafas ajedrez 6hz logmar 1 :  0.19952552079705954
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 6hz logmar 2 :  1.419832897207943
#  STD SNR para SNR sin gafas ajedrez 6hz logmar 2 :  0.3014102338719855
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 6hz logmar 3 :  1.380865656274354
#  STD SNR para SNR sin gafas ajedrez 6hz logmar 3 :  0.22293300708458633
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 6hz logmar 4 :  1.3932133762677212
#  STD SNR para SNR sin gafas ajedrez 6hz logmar 4 :  0.37740846404602596
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 6hz logmar 5 :  1.4021473656184404
#  STD SNR para SNR sin gafas ajedrez 6hz logmar 5 :  0.2925122737104888
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 6hz logmar 6 :  1.4883502715983532
#  STD SNR para SNR sin gafas ajedrez 6hz logmar 6 :  0.22273299475926764
#  --------------------------
# promedio SNR para SNR sin gafas ajedrez 6hz logmar 7 :  1.5099975874657545
#  STD SNR para SNR sin gafas ajedrez 6hz logmar 7 :  0.3836344116754477
#  --------------------------

# %%
path_2021_G = '/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/2021/Potencias_sujetos_con_gafas'

# %%
for kfg in os.listdir(path_2021_G):

  if len(kfg) == 40 :

    comparisson = kfg[len(kfg)-25:]

    for pfg in os.listdir(path_2021_G):

      comparisson_2 = pfg[len(pfg)-25:]

      if (comparisson == comparisson_2) and (len(kfg) < len(pfg)) :

        potency_file_wg = os.path.join(path_2021_G, kfg)

        potency_file_sg = os.path.join(path_2021_G, pfg)

        potency_df_wg = pd.read_csv(potency_file_wg, index_col = 0)

        potency_df_sg = pd.read_csv(potency_file_sg, index_col = 0)

        potency_df_wg.drop([12,17], inplace = True)

        potency_df_wg.reset_index(inplace= True, drop = True)
        
        if '5hz' in pfg and '5hz' in kfg:

          matlab_file = pd.concat([potency_df_sg['5.0'], potency_df_wg['5.0'], potency_df_sg['10.0'], potency_df_wg['10.0'] ], axis = 1)

          scipy.io.savemat('/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/' + kfg[0:len(kfg)-4] + '_stats.mat', mdict={'matlab': matlab_file.values})

        if '6hz' in pfg and '6hz' in kfg:

          matlab_file = pd.concat([potency_df_sg['6.0'], potency_df_wg['6.0'], potency_df_sg['10.0'], potency_df_wg['10.0'] ], axis = 1)

          scipy.io.savemat('/content/drive/MyDrive/Visión Sábados/Codigos/Procesamiento/' + kfg[0:len(kfg)-4] + '_stats.mat', mdict={'matlab': matlab_file.values})
